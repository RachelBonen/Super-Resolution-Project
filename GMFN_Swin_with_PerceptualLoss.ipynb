# %%
# !pip install -q torchmetrics[image]  # for FID (includes torch-fidelity and scipy)
# !pip install -q scikit-image        # for PSNR/SSIM if not pre-installed
from torchmetrics.image.fid import FrechetInceptionDistance
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 71.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 56.1 MB/s eta 0:00:00

# %%
# Import libraries
import os
import math
import random
import numpy as np
from PIL import Image
import cv2  # OpenCV for color space conversion
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
#from torchmetrics.image.fid import FrechetInceptionDistance
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
import torch.nn.functional as F
import torch.nn.functional as F
from torchvision import models
import matplotlib.pyplot as plt
import torchvision.transforms.functional as TF

# Check GPU availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", device)

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Using device: cuda
# Mounted at /content/drive

# %%
os.makedirs('/content/drive/MyDrive/div2k', exist_ok=True)
os.makedirs('/content/drive/MyDrive/div2k/DIV2K_train_HR', exist_ok=True)

# Download DIV2K dataset (train HR, train LR X4, val HR, val LR X4)

dataset_urls = {
    "train_hr": "http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip",
    "train_lr_x4": "http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_bicubic_X4.zip",
    "valid_hr": "http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip",
    "valid_lr_x4": "http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_bicubic_X4.zip"
}
for name, url in dataset_urls.items():
    zip_path = f"{name}.zip"
    if not os.path.exists(zip_path) and not os.path.exists(f"/content/drive/MyDrive/div2k/DIV2K_{name.replace('_', '_').capitalize()}"):
        print(f"Downloading {name}...")
        os.system(f"wget -q -O {zip_path} {url}")
        print(f"Extracting {name}...")
        os.system(f"unzip -q {zip_path} -d /content/drive/MyDrive/div2k")
# Out:
# Downloading train_hr...
# Extracting train_hr...
# Downloading train_lr_x4...
# Extracting train_lr_x4...
# Downloading valid_hr...
# Extracting valid_hr...
# Downloading valid_lr_x4...
# Extracting valid_lr_x4...

# %%
# Define a PyTorch Dataset for DIV2K
class Div2KDataset(Dataset):
    def __init__(self, hr_dir, lr_dir, train=True):
        self.hr_dir = hr_dir
        self.lr_dir = lr_dir
        self.train = train
        # List all image file names in the directory

        hr_files = sorted([f for f in os.listdir(hr_dir) if f.endswith('.png') or f.endswith('.jpg')])
        lr_files = sorted([f for f in os.listdir(lr_dir) if f.endswith('.png') or f.endswith('.jpg')])
        # Filter to matching pairs (by prefix)
        # For LR, filenames contain 'x4' suffix before extension
        if self.train:
            # Use all files (should be 800 for training)
            self.hr_files = hr_files
            self.lr_files = lr_files
        else:
            # Use all validation files (100 images)
            self.hr_files = hr_files
            self.lr_files = lr_files
        assert len(self.hr_files) == len(self.lr_files), "HR/LR file count mismatch"
        self.length = len(self.hr_files)

        if self.train:
            self.transform = transforms.Compose([
                transforms.ToTensor()  # will convert to [0,1] float and CxHxW
            ])
        else:
            # For validation, just ToTensor (no random augmentation)
            self.transform = transforms.ToTensor()

    def __len__(self):
        # For training, we will sample patches, but we define length as number of images
        return self.length

    def __getitem__(self, idx):
        # Load HR and LR images
        hr_path = os.path.join(self.hr_dir, self.hr_files[idx])
        lr_path = os.path.join(self.lr_dir, self.lr_files[idx])
        # Open images
        hr_img = Image.open(hr_path).convert("RGB")
        lr_img = Image.open(lr_path).convert("RGB")
        if self.train:
            # Random crop on the fly to 48x48 LR patch and corresponding 192x192 HR patch
            hr_width, hr_height = hr_img.size  # PIL gives (width, height)
            # Ensure HR size is divisible by 4 (should be in dataset)
            # Compute LR size
            lr_width, lr_height = hr_width // 4, hr_height // 4
            # Random top-left for LR patch
            crop_x = random.randint(0, lr_width - 48)
            crop_y = random.randint(0, lr_height - 48)
            # Compute corresponding HR crop coords
            hr_x = crop_x * 4
            hr_y = crop_y * 4
            # Crop images
            lr_img = lr_img.crop((crop_x, crop_y, crop_x + 48, crop_y + 48))
            hr_img = hr_img.crop((hr_x, hr_y, hr_x + 192, hr_y + 192))
            # Random horizontal flip
            if random.random() < 0.5:
                lr_img = lr_img.transpose(Image.FLIP_LEFT_RIGHT)
                hr_img = hr_img.transpose(Image.FLIP_LEFT_RIGHT)
            # Random vertical flip
            if random.random() < 0.5:
                lr_img = lr_img.transpose(Image.FLIP_TOP_BOTTOM)
                hr_img = hr_img.transpose(Image.FLIP_TOP_BOTTOM)
            # Random 90° rotations
            rot_times = random.randint(0, 3)
            if rot_times:
                lr_img = lr_img.rotate(90 * rot_times, expand=True)
                hr_img = hr_img.rotate(90 * rot_times, expand=True)
        else:
            # No cropping for validation; use full image
            # However, to ensure dimensions are multiples of 4, we can crop off a few pixels if needed
            #w, h = lr_img.size
            #new_w = w - (w % 1)  # LR width should already be integer (likely no need to crop)
            #new_h = h - (h % 1)
            #if new_w != w or new_h != h:
            #    lr_img = lr_img.crop((0, 0, new_w, new_h))
            #    hr_img = hr_img.crop((0, 0, new_w*4, new_h*4))

            # Crop LR to be divisible by 8, and HR accordingly
            lr_w, lr_h = lr_img.size
            new_w = lr_w - (lr_w % 8)
            new_h = lr_h - (lr_h % 8)
            lr_img = lr_img.crop((0, 0, new_w, new_h))
            hr_img = hr_img.crop((0, 0, new_w * 4, new_h * 4))

        # Transform to tensor [0,1]
        lr_tensor = self.transform(lr_img)
        hr_tensor = self.transform(hr_img)
        return lr_tensor, hr_tensor

# Initialize datasets
train_dataset = Div2KDataset(hr_dir="/content/drive/MyDrive/div2k/DIV2K_train_HR", lr_dir="/content/drive/MyDrive/div2k/DIV2K_train_LR_bicubic/X4", train=True)
val_dataset   = Div2KDataset(hr_dir="/content/drive/MyDrive/div2k/DIV2K_valid_HR",  lr_dir="/content/drive/MyDrive/div2k/DIV2K_valid_LR_bicubic/X4", train=False)

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2, pin_memory=True)
val_loader   = DataLoader(val_dataset, batch_size=1, shuffle=False)  # batch_size=1 for evaluation (one image at a time)
print(f"Loaded {len(train_dataset)} training images and {len(val_dataset)} validation images.")
# Out:
# Loaded 800 training images and 100 validation images.

# %%
def window_partition(x, window_size):
    B, C, H, W = x.shape
    x = x.view(B, C, H // window_size, window_size, W // window_size, window_size)
    x = x.permute(0, 2, 4, 3, 5, 1).contiguous()
    windows = x.view(-1, window_size, window_size, C)
    return windows

def window_reverse(windows, window_size, H, W):
    B = int(windows.shape[0] / (H * W / window_size / window_size))
    x = windows.view(B, H // window_size, W // window_size, window_size, window_size, -1)
    x = x.permute(0, 5, 1, 3, 2, 4).contiguous()
    x = x.view(B, x.shape[1], H, W)
    return x

class WindowAttention(nn.Module):
    def __init__(self, dim, window_size, num_heads):
        super().__init__()
        self.dim = dim
        self.window_size = window_size
        self.num_heads = num_heads
        self.scale = (dim // num_heads) ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=True)
        self.attn_proj = nn.Linear(dim, dim)

    def forward(self, x):
        B_, N, C = x.shape
        qkv = self.qkv(x).reshape(B_, N, 3, self.num_heads, C // self.num_heads)
        q, k, v = qkv.permute(2, 0, 3, 1, 4)

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = F.softmax(attn, dim=-1)
        out = (attn @ v).transpose(1, 2).reshape(B_, N, C)
        return self.attn_proj(out)

class SwinTransformerBlock(nn.Module):
    def __init__(self, dim, input_resolution, num_heads=4, window_size=8, shift_size=0, mlp_ratio=4.0):
        super().__init__()
        self.dim = dim
        self.input_resolution = input_resolution
        self.num_heads = num_heads
        self.window_size = window_size
        self.shift_size = shift_size
        assert 0 <= shift_size < window_size

        self.norm1 = nn.LayerNorm(dim)
        self.attn = WindowAttention(dim, window_size, num_heads)

        self.norm2 = nn.LayerNorm(dim)
        self.mlp = nn.Sequential(
            nn.Linear(dim, int(dim * mlp_ratio)),
            nn.GELU(),
            nn.Linear(int(dim * mlp_ratio), dim)
        )

    def forward(self, x):
        B, C, H, W = x.shape
        shortcut = x
        x = x.permute(0, 2, 3, 1).contiguous().view(B, H * W, C)
        x = self.norm1(x).view(B, H, W, C).permute(0, 3, 1, 2)

        if self.shift_size > 0:
            shifted_x = torch.roll(x, shifts=(-self.shift_size, -self.shift_size), dims=(2, 3))
        else:
            shifted_x = x

        x_windows = window_partition(shifted_x, self.window_size)
        x_windows = x_windows.view(-1, self.window_size * self.window_size, C)

        attn_windows = self.attn(x_windows)
        attn_windows = attn_windows.view(-1, self.window_size, self.window_size, C)
        shifted_x = window_reverse(attn_windows, self.window_size, H, W)

        if self.shift_size > 0:
            x = torch.roll(shifted_x, shifts=(self.shift_size, self.shift_size), dims=(2, 3))
        else:
            x = shifted_x

        x = x + shortcut
        x_res = x.permute(0, 2, 3, 1).contiguous().view(B, H * W, C)
        x_res = self.norm2(x_res)
        x_res = self.mlp(x_res).view(B, H, W, C).permute(0, 3, 1, 2)

        return x + x_res

# %%
class ConvBlock(nn.Sequential):
    def __init__(self, in_ch, out_ch, kernel_size=3, stride=1, padding=1):
        super().__init__(
            nn.Conv2d(in_ch, out_ch, kernel_size, stride, padding),
            nn.ReLU(inplace=True)
        )

class ResidualDenseBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.block = nn.Sequential(
            ConvBlock(channels, channels),
            ConvBlock(channels, channels),
            ConvBlock(channels, channels),
            ConvBlock(channels, channels)
        )

    def forward(self, x):
        return x + self.block(x)

class GFMRDB(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.rdb1 = ResidualDenseBlock(channels)
        self.rdb2 = ResidualDenseBlock(channels)
        self.rdb3 = ResidualDenseBlock(channels)
        self.conv = nn.Conv2d(channels * 3, channels, kernel_size=1)

    def forward(self, x):
        out1 = self.rdb1(x)
        out2 = self.rdb2(out1)
        out3 = self.rdb3(out2)
        concat = torch.cat([out1, out2, out3], dim=1)
        return self.conv(concat)

class GatedFeedbackModule(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.gate = nn.Sequential(
            nn.Conv2d(channels * 2, channels, kernel_size=1),
            nn.Sigmoid()
        )
        self.update = nn.Conv2d(channels * 2, channels, kernel_size=1)

    def forward(self, x, prev_state):
        if prev_state is None:
            return x
        concat = torch.cat([x, prev_state], dim=1)
        gate = self.gate(concat)
        update = self.update(concat)
        return gate * x + (1 - gate) * update

class GMFN_Swin(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, feature_dim=256, num_iters=3, input_resolution=(64, 64)):
        super().__init__()
        self.num_iters = num_iters
        self.head = nn.Conv2d(in_channels, feature_dim, kernel_size=3, padding=1)
        self.rdb = GFMRDB(feature_dim)
        self.gfm = GatedFeedbackModule(feature_dim)
        self.upsample = nn.Sequential(
            nn.Conv2d(feature_dim, feature_dim * 4, kernel_size=3, padding=1),
            nn.PixelShuffle(2),
            nn.Conv2d(feature_dim, feature_dim * 4, kernel_size=3, padding=1),
            nn.PixelShuffle(2),
            nn.Conv2d(feature_dim, out_channels, kernel_size=3, padding=1)
        )
        self.swin_block = SwinTransformerBlock(
            dim=feature_dim,
            input_resolution=input_resolution,
            num_heads=4,
            window_size=8,
            shift_size=4
        )

    def forward(self, x):
        feat = self.head(x)
        state = None
        for _ in range(self.num_iters):
            feat = self.rdb(feat)
            feat = self.swin_block(feat)
            feat = self.gfm(feat, state)
            state = feat
        out = self.upsample(feat)
        return out, feat  # return both for training/inference visualization

# %%
class PerceptualLoss(nn.Module):
    def __init__(self, layer='relu3_3', weight=1.0):
        super(PerceptualLoss, self).__init__()
        vgg = models.vgg19(pretrained=True).features.eval()
        for param in vgg.parameters():
            param.requires_grad = False


        self.slice = nn.Sequential()
        layer_map = {
            'relu1_2': 3,
            'relu2_2': 8,
            'relu3_3': 15,
            'relu4_2': 22
        }
        self.slice = nn.Sequential(*[vgg[i] for i in range(layer_map[layer]+1)])
        for param in self.slice.parameters():
            param.requires_grad = False
        self.weight = weight


    def forward(self, sr, hr):

        device = sr.device
        self.slice = self.slice.to(device)
        mean = torch.tensor([0.485, 0.456, 0.406], device=sr.device).view(1, 3, 1, 1)
        std  = torch.tensor([0.229, 0.224, 0.225], device=sr.device).view(1, 3, 1, 1)

        sr_norm = (sr - mean) / std
        hr_norm = (hr - mean) / std

        sr_feat = self.slice(sr_norm)
        hr_feat = self.slice(hr_norm)

        perceptual_loss = F.l1_loss(sr_feat, hr_feat)
        return self.weight * perceptual_loss

class CombinedLoss(nn.Module):
    def __init__(self, lambda_perc=1.0):
        super(CombinedLoss, self).__init__()
        self.l1 = nn.L1Loss()
        self.perc = PerceptualLoss(layer='relu3_3', weight=lambda_perc)

    def forward(self, sr, hr):
        loss_l1 = self.l1(sr, hr)
        loss_perc = self.perc(sr, hr)
        return loss_l1 + loss_perc

# %%
model = GMFN_Swin(
    in_channels=3,
    out_channels=3,
    feature_dim=256,
    num_iters=3,
    input_resolution=(64, 64)
).to(device)

# %%
# Training hyperparameters
num_epochs = 30
learning_rate = 1e-4
criterion = CombinedLoss(lambda_perc=1.0)

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)
train_loss_list = []
val_loss_list = []
for epoch in range(1, num_epochs + 1):
    model.train()
    running_loss = 0.0
    for i, (lr, hr) in enumerate(train_loader, start=1):
        lr = lr.to(device)
        hr = hr.to(device)
        optimizer.zero_grad()

        # Forward pass
        sr_final, _ = model(lr)

        # Loss only on final SR output
        loss = criterion(sr_final, hr)

        # Backward and optimize
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        if i % 50 == 0:
            avg_loss = running_loss / 50
            train_loss_list.append(avg_loss)
            running_loss = 0.0
            print(f"Epoch [{epoch}/{num_epochs}] Batch {i}: Avg Loss = {avg_loss:.4f}")

    scheduler.step()

    # Evaluation after epoch
    model.eval()
    with torch.no_grad():
        psnr_sum = 0.0
        ssim_sum = 0.0
        val_loss_sum = 0.0
        for lr, hr in val_loader:
            lr = lr.to(device)
            hr_tensor = hr.to(device)  # עבור חישוב הפסד
            hr_np = hr.numpy()         # עבור PSNR/SSIM

            # Run model
            sr, _ = model(lr)
            sr_clamped = sr.clamp(0.0, 1.0)

            # Loss
            val_loss = criterion(sr_clamped, hr_tensor)
            val_loss_sum += val_loss.item()



            sr_img = (sr_clamped[0].cpu().numpy().transpose(1, 2, 0) * 255.0).astype(np.uint8)
            hr_img = (hr_np[0].transpose(1, 2, 0) * 255.0).astype(np.uint8)
            #sr_img = (sr[0].transpose(1,2,0) * 255.0).astype(np.uint8)
            #hr_img = (hr[0].transpose(1,2,0) * 255.0).astype(np.uint8)

            sr_y = cv2.cvtColor(sr_img, cv2.COLOR_RGB2YCrCb)[:,:,0]
            hr_y = cv2.cvtColor(hr_img, cv2.COLOR_RGB2YCrCb)[:,:,0]

            psnr_val = peak_signal_noise_ratio(hr_y, sr_y, data_range=255)
            ssim_val = structural_similarity(hr_y, sr_y, data_range=255)

            psnr_sum += psnr_val
            ssim_sum += ssim_val



        avg_psnr = psnr_sum / len(val_dataset)
        avg_ssim = ssim_sum / len(val_dataset)
        avg_loss = val_loss_sum / len(val_dataset)
        val_loss_list.append(avg_loss)
        #print(f"Validation - Epoch {epoch}: PSNR = {avg_psnr:.2f} dB, SSIM = {avg_ssim:.4f}")
        print(f"Validation - Epoch {epoch}: Avg Loss = {avg_loss:.4f}, PSNR = {avg_psnr:.2f} dB, SSIM = {avg_ssim:.4f}")

    # Save weights
    save_path = f"/content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch{epoch}.pth"
    torch.save(model.state_dict(), save_path)
    print(f"Model saved to {save_path}")
# Out:
# Epoch [1/30] Batch 50: Avg Loss = 2.3497
# Validation - Epoch 1: Avg Loss = 1.6099, PSNR = 12.36 dB, SSIM = 0.0709
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch1.pth
# Epoch [2/30] Batch 50: Avg Loss = 1.7387
# Validation - Epoch 2: Avg Loss = 1.5103, PSNR = 16.65 dB, SSIM = 0.1252
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch2.pth
# Epoch [3/30] Batch 50: Avg Loss = 1.6934
# Validation - Epoch 3: Avg Loss = 1.4808, PSNR = 17.91 dB, SSIM = 0.1501
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch3.pth
# Epoch [4/30] Batch 50: Avg Loss = 1.6119
# Validation - Epoch 4: Avg Loss = 1.4519, PSNR = 19.21 dB, SSIM = 0.2212
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch4.pth
# Epoch [5/30] Batch 50: Avg Loss = 1.5795
# Validation - Epoch 5: Avg Loss = 1.4419, PSNR = 19.74 dB, SSIM = 0.2652
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch5.pth
# Epoch [6/30] Batch 50: Avg Loss = 1.5837
# Validation - Epoch 6: Avg Loss = 1.4248, PSNR = 19.85 dB, SSIM = 0.2509
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch6.pth
# Epoch [7/30] Batch 50: Avg Loss = 1.5633
# Validation - Epoch 7: Avg Loss = 1.4224, PSNR = 19.83 dB, SSIM = 0.2662
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch7.pth
# Epoch [8/30] Batch 50: Avg Loss = 1.5302
# Validation - Epoch 8: Avg Loss = 1.3805, PSNR = 21.32 dB, SSIM = 0.4149
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch8.pth
# Epoch [9/30] Batch 50: Avg Loss = 1.5027
# Validation - Epoch 9: Avg Loss = 1.3650, PSNR = 21.10 dB, SSIM = 0.3930
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch9.pth
# Epoch [10/30] Batch 50: Avg Loss = 1.4585
# Validation - Epoch 10: Avg Loss = 1.3193, PSNR = 23.57 dB, SSIM = 0.5927
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch10.pth
# Epoch [11/30] Batch 50: Avg Loss = 1.4336
# Validation - Epoch 11: Avg Loss = 1.2580, PSNR = 25.01 dB, SSIM = 0.6956
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch11.pth
# Epoch [12/30] Batch 50: Avg Loss = 1.3772
# Validation - Epoch 12: Avg Loss = 1.2483, PSNR = 25.19 dB, SSIM = 0.6773
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch12.pth
# Epoch [13/30] Batch 50: Avg Loss = 1.3658
# Validation - Epoch 13: Avg Loss = 1.2414, PSNR = 24.41 dB, SSIM = 0.6783
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch13.pth
# Epoch [14/30] Batch 50: Avg Loss = 1.3142
# Validation - Epoch 14: Avg Loss = 1.1948, PSNR = 25.39 dB, SSIM = 0.7164
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch14.pth
# Epoch [15/30] Batch 50: Avg Loss = 1.2477
# Validation - Epoch 15: Avg Loss = 1.1672, PSNR = 25.85 dB, SSIM = 0.7432
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch15.pth
# Epoch [16/30] Batch 50: Avg Loss = 1.2444
# Validation - Epoch 16: Avg Loss = 1.1449, PSNR = 25.62 dB, SSIM = 0.7328
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch16.pth
# Epoch [17/30] Batch 50: Avg Loss = 1.2589
# Validation - Epoch 17: Avg Loss = 1.1387, PSNR = 25.82 dB, SSIM = 0.7326
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch17.pth
# Epoch [18/30] Batch 50: Avg Loss = 1.2263
# Validation - Epoch 18: Avg Loss = 1.1482, PSNR = 25.70 dB, SSIM = 0.7288
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch18.pth
# Epoch [19/30] Batch 50: Avg Loss = 1.2260
# Validation - Epoch 19: Avg Loss = 1.1245, PSNR = 25.90 dB, SSIM = 0.7359
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch19.pth
# Epoch [20/30] Batch 50: Avg Loss = 1.2167
# Validation - Epoch 20: Avg Loss = 1.1179, PSNR = 25.50 dB, SSIM = 0.7382
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch20.pth
# Epoch [21/30] Batch 50: Avg Loss = 1.1850
# Validation - Epoch 21: Avg Loss = 1.1063, PSNR = 23.86 dB, SSIM = 0.7163
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch21.pth
# Epoch [22/30] Batch 50: Avg Loss = 1.1812
# Validation - Epoch 22: Avg Loss = 1.0756, PSNR = 26.22 dB, SSIM = 0.7517
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch22.pth
# Epoch [23/30] Batch 50: Avg Loss = 1.1439
# Validation - Epoch 23: Avg Loss = 1.0699, PSNR = 25.94 dB, SSIM = 0.7547
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch23.pth
# Epoch [24/30] Batch 50: Avg Loss = 1.1436
# Validation - Epoch 24: Avg Loss = 1.0765, PSNR = 25.93 dB, SSIM = 0.7540
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch24.pth
# Epoch [25/30] Batch 50: Avg Loss = 1.1421
# Validation - Epoch 25: Avg Loss = 1.0670, PSNR = 26.14 dB, SSIM = 0.7527
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch25.pth
# Epoch [26/30] Batch 50: Avg Loss = 1.1521
# Validation - Epoch 26: Avg Loss = 1.0701, PSNR = 26.05 dB, SSIM = 0.7549
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch26.pth
# Epoch [27/30] Batch 50: Avg Loss = 1.1329
# Validation - Epoch 27: Avg Loss = 1.0793, PSNR = 26.03 dB, SSIM = 0.7428
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch27.pth
# Epoch [28/30] Batch 50: Avg Loss = 1.1613
# Validation - Epoch 28: Avg Loss = 1.0636, PSNR = 26.03 dB, SSIM = 0.7528
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch28.pth
# Epoch [29/30] Batch 50: Avg Loss = 1.1531
# Validation - Epoch 29: Avg Loss = 1.0708, PSNR = 24.33 dB, SSIM = 0.7460
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch29.pth
# Epoch [30/30] Batch 50: Avg Loss = 1.1529
# Validation - Epoch 30: Avg Loss = 1.0558, PSNR = 26.06 dB, SSIM = 0.7488
# Model saved to /content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch30.pth

# %%
plt.plot(train_loss_list, label='Training Loss')
plt.plot(val_loss_list, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
model = GMFN_Swin(
    in_channels=3,
    out_channels=3,
    feature_dim=256,
    num_iters=3,
    input_resolution=(64, 64)
).to(device)
checkpoint_path = "/content/drive/MyDrive/div2k/GMFN_Swin_with_PerceptualLoss_x4_DIV2K_epoch100.pth"

model.load_state_dict(torch.load(checkpoint_path, map_location=device))
model.eval()
# Out:
# GMFN_Swin(
#   (head): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (rdb): GFMRDB(
#     (rdb1): ResidualDenseBlock(
#       (block): Sequential(
#         (0): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (2): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (3): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#     )
#     (rdb2): ResidualDenseBlock(
#       (block): Sequential(
#         (0): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (2): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (3): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#     )
#     (rdb3): ResidualDenseBlock(
#       (block): Sequential(
#         (0): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (2): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (3): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#     )
#     (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (gfm): GatedFeedbackModule(
#     (gate): Sequential(
#       (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): Sigmoid()
#     )
#     (update): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (upsample): Sequential(
#     (0): Conv2d(256, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): PixelShuffle(upscale_factor=2)
#     (2): Conv2d(256, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): PixelShuffle(upscale_factor=2)
#     (4): Conv2d(256, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (swin_block): SwinTransformerBlock(
#     (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (attn): WindowAttention(
#       (qkv): Linear(in_features=256, out_features=768, bias=True)
#       (attn_proj): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (mlp): Sequential(
#       (0): Linear(in_features=256, out_features=1024, bias=True)
#       (1): GELU(approximate='none')
#       (2): Linear(in_features=1024, out_features=256, bias=True)
#     )
#   )
# )

# %%
# Switch model to eval mode for evaluation
model.eval()

# Initialize metric accumulators
psnr_sum = 0.0
ssim_sum = 0.0
fid_metric = FrechetInceptionDistance(feature=2048).to(device)  # use Inception pool3 features (2048-dim)

with torch.no_grad():
    for lr, hr in val_loader:
        lr = lr.to(device)
        hr = hr.to(device)
        # Get SR output
        sr, _ = model(lr)
        # Clamp and convert to uint8 for metrics
        sr_uint8 = (sr.clamp(0.0, 1.0) * 255).byte()
        hr_uint8 = (hr.clamp(0.0, 1.0) * 255).byte()
        # Calculate PSNR and SSIM on Y channel
        sr_img = sr_uint8[0].permute(1,2,0).cpu().numpy()  # HxWxC
        hr_img = hr_uint8[0].permute(1,2,0).cpu().numpy()
        sr_y = cv2.cvtColor(sr_img, cv2.COLOR_RGB2YCrCb)[:,:,0]
        hr_y = cv2.cvtColor(hr_img, cv2.COLOR_RGB2YCrCb)[:,:,0]
        psnr_val = peak_signal_noise_ratio(hr_y, sr_y, data_range=255)
        ssim_val = structural_similarity(hr_y, sr_y, data_range=255)
        psnr_sum += psnr_val
        ssim_sum += ssim_val
        # Update FID metrics
        fid_metric.update(hr_uint8, real=True)
        fid_metric.update(sr_uint8, real=False)
        print(f"PSNR: {psnr_val:.2f} dB, SSIM: {ssim_val:.4f}")
# Compute average PSNR, SSIM
avg_psnr = psnr_sum / len(val_dataset)
avg_ssim = ssim_sum / len(val_dataset)
# Compute FID
fid_value = fid_metric.compute().item()

print(f"Validation PSNR (Y-channel): {avg_psnr:.2f} dB")
print(f"Validation SSIM (Y-channel): {avg_ssim:.4f}")
print(f"Validation FID: {fid_value:.2f}")
# Out:
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100%|██████████| 91.2M/91.2M [00:02<00:00, 39.4MB/s]
# PSNR: 27.22 dB, SSIM: 0.7927
# PSNR: 32.87 dB, SSIM: 0.8727
# PSNR: 33.65 dB, SSIM: 0.9337
# PSNR: 25.52 dB, SSIM: 0.7359
# PSNR: 27.19 dB, SSIM: 0.7373
# PSNR: 26.78 dB, SSIM: 0.8172
# PSNR: 19.48 dB, SSIM: 0.4420
# PSNR: 25.40 dB, SSIM: 0.7728
# PSNR: 30.15 dB, SSIM: 0.8121
# PSNR: 25.45 dB, SSIM: 0.7391
# PSNR: 27.28 dB, SSIM: 0.7360
# PSNR: 25.53 dB, SSIM: 0.7466
# PSNR: 28.76 dB, SSIM: 0.8421
# PSNR: 26.49 dB, SSIM: 0.8624
# PSNR: 32.17 dB, SSIM: 0.8954
# PSNR: 29.45 dB, SSIM: 0.7940
# PSNR: 30.09 dB, SSIM: 0.8492
# PSNR: 26.50 dB, SSIM: 0.8545
# PSNR: 26.36 dB, SSIM: 0.7620
# PSNR: 21.72 dB, SSIM: 0.6941
# PSNR: 25.06 dB, SSIM: 0.8172
# PSNR: 27.58 dB, SSIM: 0.8004
# PSNR: 24.27 dB, SSIM: 0.7599
# PSNR: 25.49 dB, SSIM: 0.8378
# PSNR: 24.83 dB, SSIM: 0.7502
# PSNR: 22.81 dB, SSIM: 0.6952
# PSNR: 30.47 dB, SSIM: 0.8382
# PSNR: 16.08 dB, SSIM: 0.6827
# PSNR: 25.82 dB, SSIM: 0.5080
# PSNR: 23.75 dB, SSIM: 0.6940
# PSNR: 26.75 dB, SSIM: 0.7959
# PSNR: 27.68 dB, SSIM: 0.8257
# PSNR: 30.05 dB, SSIM: 0.8692
# PSNR: 24.44 dB, SSIM: 0.7406
# PSNR: 22.05 dB, SSIM: 0.5395
# PSNR: 23.28 dB, SSIM: 0.7130
# PSNR: 23.76 dB, SSIM: 0.7417
# PSNR: 36.48 dB, SSIM: 0.8906
# PSNR: 27.87 dB, SSIM: 0.7954
# PSNR: 26.75 dB, SSIM: 0.7686
# PSNR: 26.18 dB, SSIM: 0.7980
# PSNR: 28.08 dB, SSIM: 0.8223
# PSNR: 37.42 dB, SSIM: 0.9723
# PSNR: 38.38 dB, SSIM: 0.9734
# PSNR: 21.48 dB, SSIM: 0.6715
# PSNR: 22.13 dB, SSIM: 0.6967
# PSNR: 25.25 dB, SSIM: 0.7556
# PSNR: 25.06 dB, SSIM: 0.6840
# PSNR: 19.66 dB, SSIM: 0.6398
# PSNR: 26.73 dB, SSIM: 0.7705
# PSNR: 26.61 dB, SSIM: 0.8403
# PSNR: 28.35 dB, SSIM: 0.7539
# PSNR: 31.25 dB, SSIM: 0.9070
# PSNR: 23.37 dB, SSIM: 0.6856
# PSNR: 27.86 dB, SSIM: 0.7123
# PSNR: 24.75 dB, SSIM: 0.6442
# PSNR: 33.94 dB, SSIM: 0.7814
# PSNR: 26.55 dB, SSIM: 0.7089
# PSNR: 23.86 dB, SSIM: 0.6278
# PSNR: 19.53 dB, SSIM: 0.5507
# PSNR: 20.99 dB, SSIM: 0.6325
# PSNR: 32.17 dB, SSIM: 0.8039
# PSNR: 31.92 dB, SSIM: 0.8857
# PSNR: 28.31 dB, SSIM: 0.7346
# PSNR: 26.30 dB, SSIM: 0.7274
# PSNR: 24.33 dB, SSIM: 0.7690
# PSNR: 25.83 dB, SSIM: 0.7736
# PSNR: 29.70 dB, SSIM: 0.9362
# PSNR: 22.65 dB, SSIM: 0.7477
# PSNR: 26.55 dB, SSIM: 0.7996
# PSNR: 29.54 dB, SSIM: 0.8541
# PSNR: 22.29 dB, SSIM: 0.6332
# PSNR: 22.58 dB, SSIM: 0.6606
# PSNR: 28.21 dB, SSIM: 0.7356
# PSNR: 22.30 dB, SSIM: 0.5673
# PSNR: 21.00 dB, SSIM: 0.4898
# PSNR: 35.27 dB, SSIM: 0.9347
# PSNR: 28.97 dB, SSIM: 0.8474
# PSNR: 25.44 dB, SSIM: 0.8167
# PSNR: 30.23 dB, SSIM: 0.8704
# PSNR: 24.96 dB, SSIM: 0.7422
# PSNR: 31.48 dB, SSIM: 0.9331
# PSNR: 25.06 dB, SSIM: 0.6947
# PSNR: 24.53 dB, SSIM: 0.6764
# PSNR: 21.82 dB, SSIM: 0.5232
# PSNR: 33.68 dB, SSIM: 0.8976
# PSNR: 23.35 dB, SSIM: 0.7001
# PSNR: 27.75 dB, SSIM: 0.8351
# PSNR: 27.15 dB, SSIM: 0.8511
# PSNR: 24.55 dB, SSIM: 0.7083
# PSNR: 23.85 dB, SSIM: 0.7217
# PSNR: 25.20 dB, SSIM: 0.8067
# PSNR: 31.05 dB, SSIM: 0.7935
# PSNR: 29.37 dB, SSIM: 0.8519
# PSNR: 19.59 dB, SSIM: 0.5104
# PSNR: 33.58 dB, SSIM: 0.9278
# PSNR: 20.42 dB, SSIM: 0.6452
# PSNR: 31.54 dB, SSIM: 0.8890
# PSNR: 26.16 dB, SSIM: 0.8272
# PSNR: 23.88 dB, SSIM: 0.7585
# Validation PSNR (Y-channel): 26.63 dB
# Validation SSIM (Y-channel): 0.7627
# Validation FID: 31.56

# %%
def plot_sr_example(lr_tensor, sr_tensor, hr_tensor, idx=None, save_path=None, crop_box=None):
    """
    מצייר את ההשוואה בין LR, SR ו-HR.

    lr_tensor: טנסור [1, 3, H, W] או [3, H, W]
    sr_tensor: טנסור [1, 3, H, W] או [3, H, W]
    hr_tensor: טנסור [1, 3, H, W] או [3, H, W]
    idx: אינדקס להצגה בכותרת (אופציונלי)
    save_path: אם יש נתיב, ישמור לשם את האיור כ־PNG
    crop_box: tuple (left, upper, right, lower) – לחיתוך אזור ספציפי להשוואה
    """
    def tensor_to_np(t):
        if t.dim() == 4:
            t = t[0]
        img = t.cpu().clamp(0, 1).permute(1, 2, 0).numpy()
        return (img * 255).astype(np.uint8)

    lr = tensor_to_np(lr_tensor)
    sr = tensor_to_np(sr_tensor)
    hr = tensor_to_np(hr_tensor)

    if crop_box:
        lr = TF.crop(TF.to_pil_image(torch.tensor(lr).permute(2, 0, 1).float() / 255), *[c//4 for c in crop_box])
        sr = TF.crop(TF.to_pil_image(torch.tensor(sr).permute(2, 0, 1).float() / 255), *crop_box)
        hr = TF.crop(TF.to_pil_image(torch.tensor(hr).permute(2, 0, 1).float() / 255), *crop_box)
        lr = np.array(lr)
        sr = np.array(sr)
        hr = np.array(hr)

    titles = ['Low-Resolution (LR)', 'Super-Resolved (SR)', 'High-Resolution (HR)']
    images = [lr, sr, hr]

    plt.figure(figsize=(12, 4))
    for i, (img, title) in enumerate(zip(images, titles)):
        plt.subplot(1, 3, i+1)
        plt.imshow(img)
        plt.title(title, fontsize=14)
        plt.axis('off')
    if idx is not None:
        plt.suptitle(f"Example #{idx}", fontsize=16)
    if save_path:
        plt.savefig(save_path, bbox_inches='tight')
    plt.show()

# %%
lr, hr = val_dataset[27]
lr = lr.unsqueeze(0).to(device)   # [1, 3, H, W]
hr = hr.unsqueeze(0).to(device)   # [1, 3, H, W]

# הפעלת המודל
with torch.no_grad():
    sr_final, _ = model(lr)

plot_sr_example(lr, sr_final, hr, idx=27)
crop_box=(500,500,100,100)  # left, top, right, bottom ב-HR
plot_sr_example(lr, sr_final, hr, idx=27, crop_box=crop_box)

# %%
lr, hr = val_dataset[43]
lr = lr.unsqueeze(0).to(device)   # [1, 3, H, W]
hr = hr.unsqueeze(0).to(device)   # [1, 3, H, W]

# הפעלת המודל
with torch.no_grad():
    sr_final, _ = model(lr)

plot_sr_example(lr, sr_final, hr, idx=27)
crop_box = (1200, 1200, 100, 100)  # left, top, right, bottom ב-HR
plot_sr_example(lr, sr_final, hr, idx=27, crop_box=crop_box)

# %%
lr, hr = val_dataset[99]
lr = lr.unsqueeze(0).to(device)   # [1, 3, H, W]
hr = hr.unsqueeze(0).to(device)   # [1, 3, H, W]

# הפעלת המודל
with torch.no_grad():
    sr_final, _ = model(lr)

plot_sr_example(lr, sr_final, hr, idx=27)
crop_box = (120, 120, 100, 100)  # left, top, right, bottom ב-HR
plot_sr_example(lr, sr_final, hr, idx=27, crop_box=crop_box)
